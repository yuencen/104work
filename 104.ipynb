# %%
import requests
from bs4 import BeautifulSoup


url = 'https://www.104.com.tw/jobs/search/list?ro=0&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=11&asc=0&page=3&mode=s&jobsource=2018indexpoc'
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
}


res = requests.get(url,headers=headers)
res.text
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head><META HTTP-EQUIV="CONTENT-TYPE" CONTENT="TEXT/HTML; CHARSET=utf-8"/><title></title></head>\r\n<body>\r\n<SCRIPT LANGUAGE="JavaScript">\r\nwindow.location="https://www.104.com.tw/jobs/main/syserr?eid=13584908623415075718";\r\n</script>\r\n</body>\r\n</html>'

# %%
import requests
from bs4 import BeautifulSoup


url = 'https://www.104.com.tw/jobs/search/?jobsource=2018indexpoc&ro=0'
headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.82 Safari/537.36"
}

res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text,'html.parser')
jobSoupList = soup.select('article')

for jobs in jobSoupList:
    
    job = jobs.find('a',class_="js-job-link").text
    joburl = 'https:' + jobs.find('a',class_="js-job-link")['href']
    Name = jobs.get('data-cust-name')
    print(job)
    print(joburl)
    print(Name)
    print('===========')
# Out:
# 美製淨水精品銷售顧問(大台北）Water Filters Sales Representative
# https://www.104.com.tw/job/4vojb?jobsource=hotjob_chr&ro=0
# 偉太健康科技有限公司
# ...
# 全端 (前/後端) 軟體工程師 (.NET C#)
# https://www.104.com.tw/job/5w81m?jobsource=hotjob_chr&ro=0
# 希格斯資訊科技有限公司
# ...
# 雙語國家來臨 打造雙語教育第一步 徵課程體驗規劃師(新人起薪+獎金4萬up)
# https://www.104.com.tw/job/6cnci?jobsource=hotjob_chr&ro=0
# TutorABC_麥奇數位股份有限公司
# ...
# SRE(服務可靠性工程師)
# https://www.104.com.tw/job/63z79?jobsource=hotjob_chr&ro=0
# 希格斯資訊科技有限公司
# ...
# 派駐南科台積電18廠安檢員  (無工作經驗可、男女不拘、需輪班)
# https://www.104.com.tw/job/30bgp?jobsource=hotjob_chr&ro=0
# 中鋼保全股份有限公司
# ...
# 【不動產經紀人員】房仲龍頭-轉職首選無經驗可(新北市新店區)
# https://www.104.com.tw/job/564p4?jobsource=hotjob_chr&ro=0
# 信義房屋股份有限公司
# ...
# 月薪37K~150K│傑昇通信擴大獵才│門市銷售人員-三重區
# https://www.104.com.tw/job/6g0b9?jobsource=hotjob_chr&ro=0
# 傑昇通信_傑升通信股份有限公司
# ...
# 全端軟體開發工程師
# https://www.104.com.tw/job/6taxy?jobsource=hotjob_chr&ro=0
# 科熱臺灣有限公司
# ...
# Online信貸網路拓展業務服務專員(inbound sales 正職, 保證月薪3萬起, 歡迎保險電銷同業轉職加入) (台北市)
# https://www.104.com.tw/job/6svhx?jobsource=hotjob_chr&ro=0
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os

folderName = '104job/'
if not os.path.exists(folderName):
    os.mkdir(folderName)

url = 'https://www.104.com.tw/jobs/search/?ro=0&expansionType=area%2Cspec%2Ccom%2Cjob%2Cwf%2Cwktm&order=11&asc=0&page=10&mode=s&jobsource=2018indexpoc'

headers = {
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36"
}


res = requests.get(url,headers=headers)
soup = BeautifulSoup(res.text,'html.parser')
jobSoupList = soup.select('article')

for jobs in jobSoupList:
    
    job = jobs.find('a',class_="js-job-link").text
    joburl = 'https:' + jobs.find('a',class_="js-job-link")['href']
    Name = jobs.get('data-cust-name')
    content = soup.find_all('p',class_="job-list-item__info b-clearfix b-content")
    
  
    print(job)
    print(joburl)
    print(Name)
    print(content)
    print('===========')
